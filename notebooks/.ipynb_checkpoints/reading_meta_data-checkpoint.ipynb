# %%
import os
import pandas as pd
import numpy as np
from tabulate import tabulate

# %% [markdown]
# ### Defining functions for meta data summary stats

# %%
def _replace_empty_strings_with_nan(meta_data_df):
    """
    Given a dataframe, replace all empty strings with np.nan
    """
    return meta_data_df.replace(r'^\s*$', np.NaN, regex=True)


def _main_cat_uniques(meta_data_df):
    """
    Given the meta data dataframe, return count(unique main categories), unique values, count(null)
    """
    _value_counts = meta_data_df['main_cat'].value_counts()
    _nulls = np.count_nonzero(pd.isna(meta_data['main_cat']))
    return len(_value_counts), _value_counts.index.values, _nulls


def _brands_uniques(mata_data_df):
    """
    Given the meta data dataframe, return count(unique brands), count(null)
    """
    _value_counts = meta_data_df['brand'].nunique()
    _nulls = np.count_nonzero(pd.isna(meta_data_df['brand']))
    return _value_counts, _nulls


def _category_enumerate_stats(meta_data_df):
    """
    Given the meta data dataframe, make individual columns based on the heirarchy in the 
    category feild, and report stats on that.
    Returns level0_uniques, level0_non_null_count, level1_uniques, level1_non_null_count, level2_uniques, level2_non_null_count
    """

def get_meta_data_stats(meta_folder_path, output_path=None, file_names=None):
        try:
            if not file_names:
                file_names = os.listdir(meta_folder_path)

            _result = list()
            for file_name in file_names:
                _temp_dict = dict()
                _file_path = '/'.join([meta_folder_path, file_name])
                data = list()
                with open(_file_path) as fp:
                    for l in fp:
                        data.append(json.loads(l.strip()))
                
                meta_data_df = pd.DataFrame(data)
                meta_data_df = _replace_empty_strings_with_nan(meta_data_df)
                
                _temp_dict['main_cat_unique'], _temp_dict['main_cat_unique_values'], _temp_dict['main_cat_nulls'] = _main_cat_uniques(meta_data_df)
                _temp_dict['brands_unique'], _temp_dict['brands_nulls'] = _brands_uniques(meta_data_df)
                _temp_dict['total_products'] = len(meta_data_df)
                _temp_dict['unique_products'] = meta_data_df['asin'].nunique()
                _temp_dict['products_with_title'] = np.count_nonzero(~pd.isna(meta_data_df['title']))
                _temp_dict['dataset'] = file_name
                _temp_dict['category_nulls_when_main_cat_present'] = np.count_nonzero(~pd)
                _result.append(_temp_dict)
            result_df = pd.DataFrame(_result)
            if output_path:
                result_df.to_csv(output_path)
            else:
                print(tabulate(result_df, headers='keys', tablefmt='psql'))
        except Exception as e:
            print(Exception)

# %%
k = pd.DataFrame([[1,np.nan,' s'],[1,1,1]], columns=['a','b','c'])
k
# Out:
#    a    b   c
# 0  1  NaN   s
# 1  1  1.0   1

# %%
replace_empty_strings_with_nan(k).iloc[0,0]
# Out:
# 1

# %%
import json
import pandas as pd
import numpy as np

meta_file_path = "/home/bigdata/Desktop/projects/Rec_Sys/file_server/dataset/_magazine_dataset/meta_Magazine_Subscriptions.json"
ratings_file_path = "/home/bigdata/Desktop/projects/Rec_Sys/file_server/dataset/_magazine_dataset/Magazine_Subscriptions.csv"

data = list()

with open(meta_file_path) as fp:
    for l in fp:
        data.append(json.loads(l.strip()))

meta_data = pd.DataFrame(data)
ratings = pd.read_csv(ratings_file_path, names = ['asin','u_id','rating'])

# %%
ratings.head()
# Out:
#          asin            u_id  rating
# 0  B00005N7P0   AH2IFH762VY5U     5.0
# 1  B00005N7P0   AOSFI0JEYU4XM     5.0
# 2  B00005N7OJ  A3JPFWKS83R49V     3.0
# 3  B00005N7OJ  A19FKU6JZQ2ECJ     5.0
# 4  B00005N7P0  A25MDGOMZ2GALN     5.0

# %%
ratings.head().to_csv("papa.csv")

# %%
meta_data.tail()
# Out:
#                                                category  \
# 3488  [Magazine Subscriptions, Sports, Recreation & ...
# 3489          [Magazine Subscriptions, Fashion & Style]
# 3490                                                NaN
# 3491                                                NaN
# 3492  [Magazine Subscriptions, Home & Garden, Antiqu...
#
#                                             description  \
# 3488  [Built for the true classic car enthusiast, ea...
# 3489  [InStyle celebrates the private side of public...
# 3490  [Sports Illustrated brings you spectacular act...
# 3491  [Get fresh ideas and inspiration on how to mak...
# 3492                                                NaN
#
#                                                also_buy  \
# 3488  [B002PXVYO6, B01FIR6AJ4, B00006KGT1, B01DPP7H5...
# 3489                                                NaN
# 3490                                                NaN
# 3491                                                NaN
# 3492  [B075HJBL8L, B01N184C5W, B01912KIV8, B0098LC1L...
#
#                                                   image  \
# 3488  [https://images-na.ssl-images-amazon.com/image...
# 3489                                                NaN
# 3490                                                NaN
# 3491                                                NaN
# 3492                                                NaN
#
#                            brand  \
# 3488  Motorsport Marketing, Inc.
# 3489        Meredith Corporation
# 3490        Meredith Corporation
# 3491        Meredith Corporation
# 3492     Greybird Publishers LLC
#
#                                               also_view  \
# 3488  [B01FV4YCNA, B00006KGT1, B002PXVYO6, B0047VIAI...
# 3489                                                NaN
# 3490                                                NaN
# 3491                                                NaN
# 3492  [B00HRF3A0S, B01912KIV8, B075HJBL8L, B01N184C5...
#
#                                                 details  \
# 3488  \n\n\n\n\n    <div class="disclaim">Subscripti...
# 3489  \n\n\n\n\n    <div class="disclaim">Subscripti...
# 3490  \n\n\n\n\n    <div class="disclaim">Subscripti...
# 3491  \n\n\n\n\n    <div class="disclaim">Subscripti...
# 3492  \n  <div class="content">\n\n\n\n\n\n\n\n<ul>\...
#
#                     main_cat        asin                         rank  \
# 3488  Magazine Subscriptions  B01HI8V1I6                          NaN
# 3489  Magazine Subscriptions  B01HI8V0ZK                          NaN
# 3490  Magazine Subscriptions  B01HI8V1C2                          NaN
# 3491  Magazine Subscriptions  B01HI8V1MC                          NaN
# 3492            Buy a Kindle  B01HIZSSQM  4,696,642PaidinKindleStore(
#
#                                                   title
# 3488                                                NaN
# 3489                                                NaN
# 3490                                                NaN
# 3491                                                NaN
# 3492  var aPageStart = (new Date()).getTime();\nvar ...

# %% [markdown]
# ### Check how many main category values are there

# %%
meta_data['main_cat'].value_counts()
# Out:
# Magazine Subscriptions    3386
# Buy a Kindle               107
# Name: main_cat, dtype: int64

# %% [markdown]
# ### Check how many 'category' values are nan

# %%
np.count_nonzero(~pd.isna(meta_data['category']))
# Out:
# 2991

# %% [markdown]
# ### Takeaway, top level category is captured in 'main_cat' and 'category' captures other sub categories. So we separate out cases where 'category' field is non empty and enumerate the subcategories as columns and finally concat with cases where category field was empty (ie they only have a top level category given in 'main_cat')
# * preserve index for concat
# * rename sub_cats according to level

# %%
meta_data_with_sub_cat = meta_data[~pd.isna(meta_data['category'])]
meta_data_without_sub_cat = meta_data[pd.isna(meta_data['category'])]

meta_data_with_sub_cat.info(), meta_data_without_sub_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2991 entries, 0 to 3492
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   category     2991 non-null   object
#  1   description  2545 non-null   object
#  2   also_buy     1630 non-null   object
#  3   image        1402 non-null   object
#  4   brand        2825 non-null   object
#  5   also_view    2100 non-null   object
#  6   details      2991 non-null   object
#  7   main_cat     2991 non-null   object
#  8   asin         2991 non-null   object
#  9   rank         1898 non-null   object
#  10  title        262 non-null    object
# dtypes: object(11)
# memory usage: 280.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 502 entries, 83 to 3491
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   category     0 non-null      object
#  1   description  366 non-null    object
#  2   also_buy     78 non-null     object
#  3   image        82 non-null     object
#  4   brand        445 non-null    object
#  5   also_view    68 non-null     object
#  6   details      502 non-null    object
#  7   main_cat     502 non-null    object
#  8   asin         502 non-null    object
#  9   rank         194 non-null    object
#  10  title        67 non-null     object
# dtypes: object(11)
# memory usage: 47.1+ KB
# (None, None)

# %%
additional_columns = pd.DataFrame(meta_data_with_sub_cat['category'].to_list())
additional_columns[~pd.isna(additional_columns[5])].sample(20)
# Out:
#                           0                            1   \
# 2465  Magazine Subscriptions      Religion & Spirituality
# 2679  Magazine Subscriptions         Lifestyle & Cultures
# 2780  Magazine Subscriptions         Lifestyle & Cultures
# 2903  Magazine Subscriptions              Fashion & Style
# 2522  Magazine Subscriptions    Arts, Music & Photography
# 2775  Magazine Subscriptions  Entertainment & Pop Culture
# 2752  Magazine Subscriptions         Lifestyle & Cultures
# 2759  Magazine Subscriptions     Automotive & Motorcycles
# 2801  Magazine Subscriptions    Arts, Music & Photography
# 2948  Magazine Subscriptions              Fashion & Style
# 2486  Magazine Subscriptions  News & Political Commentary
# 2802  Magazine Subscriptions    Arts, Music & Photography
# 2758  Magazine Subscriptions     Automotive & Motorcycles
# 2577  Magazine Subscriptions             Women's Interest
# 2287  Magazine Subscriptions  News & Political Commentary
# 2728  Magazine Subscriptions         Lifestyle & Cultures
# 2413  Magazine Subscriptions    Science, History & Nature
# 2725  Magazine Subscriptions         Lifestyle & Cultures
# 2683  Magazine Subscriptions  Entertainment & Pop Culture
# 2578  Magazine Subscriptions  Entertainment & Pop Culture
#
#                        2                        3                4   \
# 2465         Christianity  Kindle (5th Generation)  Kindle Keyboard
# 2679
# 2780
# 2903
# 2522       Graphic Design  Kindle (5th Generation)  Kindle Keyboard
# 2775
# 2752
# 2759
# 2801
# 2948                  Men
# 2486   Ideas & Commentary  Kindle (5th Generation)  Kindle Keyboard
# 2802
# 2758
# 2577
# 2287   Ideas & Commentary  Kindle (5th Generation)  Kindle Keyboard
# 2728
# 2413  Biological Sciences  Kindle (5th Generation)  Kindle Keyboard
# 2725
# 2683
# 2578
#
#              5                        6                        7   \
# 2465  Kindle DX  Kindle (2nd Generation)  Kindle (1st Generation)
# 2679                                None                     None
# 2780                                                         None
# 2903                                                         None
# 2522  Kindle DX  Kindle (2nd Generation)  Kindle (1st Generation)
# 2775
# 2752
# 2759
# 2801
# 2948
# 2486  Kindle DX  Kindle (2nd Generation)  Kindle (1st Generation)
# 2802
# 2758
# 2577                                None                     None
# 2287  Kindle DX  Kindle (2nd Generation)  Kindle (1st Generation)
# 2728
# 2413  Kindle DX  Kindle (2nd Generation)  Kindle (1st Generation)
# 2725
# 2683                                None                     None
# 2578                                                         None
#
#                      8                                   9   ...         25  \
# 2465  Kindle Paperwhite  Kindle Paperwhite (5th Generation)  ...  Fire HD 8
# 2679               None                                None  ...       None
# 2780               None                                None  ...       None
# 2903               None                                None  ...       None
# 2522  Kindle Paperwhite  Kindle Paperwhite (5th Generation)  ...  Fire HD 8
# 2775               None                                None  ...       None
# 2752                                                         ...       None
# 2759                                                         ...       None
# 2801               None                                None  ...       None
# 2948               None                                None  ...       None
# 2486  Kindle Paperwhite  Kindle Paperwhite (5th Generation)  ...  Fire HD 8
# 2802               None                                None  ...       None
# 2758                                                         ...       None
# 2577               None                                None  ...       None
# 2287  Kindle Paperwhite  Kindle Paperwhite (5th Generation)  ...  Fire HD 8
# 2728                                                         ...       None
# 2413  Kindle Paperwhite  Kindle Paperwhite (5th Generation)  ...  Fire HD 8
# 2725                                                         ...       None
# 2683               None                                None  ...       None
# 2578               None                                None  ...       None
#
#         26          27                      28                      29  \
# 2465  Fire  Fire Phone  (Version 4.1 or later)  (Version 4.1 or later)
# 2679  None        None                    None                    None
# 2780  None        None                    None                    None
# 2903  None        None                    None                    None
# 2522  Fire  Fire Phone  (Version 4.1 or later)  (Version 4.1 or later)
# 2775  None        None                    None                    None
# 2752  None        None                    None                    None
# 2759  None        None                    None                    None
# 2801  None        None                    None                    None
# 2948  None        None                    None                    None
# 2486  Fire  Fire Phone  (Version 4.1 or later)  (Version 4.1 or later)
# 2802  None        None                    None                    None
# 2758  None        None                    None                    None
# 2577  None        None                    None                    None
# 2287  Fire  Fire Phone  (Version 4.1 or later)  (Version 4.1 or later)
# 2728  None        None                    None                    None
# 2413  Fire  Fire Phone  (Version 4.1 or later)  (Version 4.1 or later)
# 2725  None        None                    None                    None
# 2683  None        None                    None                    None
# 2578  None        None                    None                    None
#
#                           30                      31                      32  \
# 2465  (Version 3.0 or later)  (Version 3.0 or later)  (Version 2.9 or later)
# 2679                    None                    None                    None
# 2780                    None                    None                    None
# 2903                    None                    None                    None
# 2522  (Version 3.0 or later)  (Version 3.0 or later)  (Version 2.9 or later)
# 2775                    None                    None                    None
# 2752                    None                    None                    None
# 2759                    None                    None                    None
# 2801                    None                    None                    None
# 2948                    None                    None                    None
# 2486  (Version 3.0 or later)  (Version 3.0 or later)  (Version 2.9 or later)
# 2802                    None                    None                    None
# 2758                    None                    None                    None
# 2577                    None                    None                    None
# 2287  (Version 3.0 or later)  (Version 3.0 or later)  (Version 2.9 or later)
# 2728                    None                    None                    None
# 2413  (Version 3.0 or later)  (Version 3.0 or later)  (Version 2.9 or later)
# 2725                    None                    None                    None
# 2683                    None                    None                    None
# 2578                    None                    None                    None
#
#         33    34
# 2465  None  None
# 2679  None  None
# 2780  None  None
# 2903  None  None
# 2522  None  None
# 2775  None  None
# 2752  None  None
# 2759  None  None
# 2801  None  None
# 2948  None  None
# 2486  None  None
# 2802  None  None
# 2758  None  None
# 2577  None  None
# 2287  None  None
# 2728  None  None
# 2413  None  None
# 2725  None  None
# 2683  None  None
# 2578  None  None
#
# [20 rows x 35 columns]

# %%
np.isnan(np.array(additional_columns.iloc[2775,0]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-268d91ea59a5> in <module>
# ----> 1 np.isnan(np.array(additional_columns.iloc[2775,0]))
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
np.isnan(23)
# Out:
# False

# %%
np.count_nonzero(~pd.isna(meta_data['title']))
# Out:
# 329
